# %% [markdown]
# # Reward-modulated RC network of Miconi
#
# Reproduction from:
#
# Miconi T. (2017). Biologically plausible learning in recurrent neural networks reproduces neural dynamics observed during cognitive tasks. eLife 6:e20899. doi:10.7554/eLife.20899

# %%
from ANNarchy import *
clear()
setup(dt=1.0)
# Out:
# ANNarchy 4.6 (4.6.8b) on linux (posix).

# %% [markdown]
# ![](img/miconi.png)
#
# Each neuron in the reservoir follows the following equations:
#
# $$
#     \tau \frac{dx(t)}{dt} + x(t) = \sum_\text{input} W^\text{IN} \, r^\text{IN}(t) + \sum_\text{rec} W^\text{REC} \, r(t) + \xi(t)
# $$
#
# $$
#     r(t) = \tanh(x(t))
# $$
#
# where $\xi(t)$ is a random perturbation at 3 Hz, with an amplitude randomly sampled between $-A$ and $+A$.
#
# We additionally keep track of the mean firing rate with a sliding average:
#
# $$
#     \tilde{x}(t) = \alpha \, \tilde{x}(t) + (1 - \alpha) \, x(t)
# $$
#
# Some neurons keep a constant rate throughout learning (1 or -1) to provide some bias to the other neurons.

# %%
neuron = Neuron(
    parameters = """
        tau = 30.0 : population # Time constant
        constant = 0.0 # The four first neurons have constant rates
        alpha = 0.05 : population # To compute the sliding mean
        f = 3.0 : population # Frequency of the perturbation
        A = 16. : population # Perturbation amplitude. dt*A/tau should be 0.5...
    """,
    equations="""
        # Perturbation
        perturbation = if Uniform(0.0, 1.0) < f/1000.: 1.0 else: 0.0 
        noise = if perturbation > 0.5: A*Uniform(-1.0, 1.0) else: 0.0

        # ODE for x
        x += dt*(sum(in) + sum(exc) - x + noise)/tau

        # Output r
        rprev = r
        r = if constant == 0.0: tanh(x) else: tanh(constant)

        # Sliding mean
        delta_x = x - x_mean
        x_mean = alpha * x_mean + (1 - alpha) * x
    """
)

# %% [markdown]
# The learning rule is defined by a trace $e_{i, j}(t)$ for each synapse $i \rightarrow j$ incremented at each time step with:
#
# $$
#     e_{i, j}(t) = e_{i, j}(t-1) + (r_i (t) \, x_j(t))^3
# $$
#
# At the end $T$ of a trial, a normalized reward $(R -R_\text{mean})$ is delivered and all weights are updated using:
#
# $$
#     \Delta w_{i, j} = - \eta \,  e_{i, j}(T) \, (R -R_\text{mean})
# $$
#
# All traces are then reset to 0 for the next trial. Weight changes are clamped between -0.0003 and 0.0003.
#
# As ANNarchy applies the synaptic equations at each tie step, we need to introduce a boolean `learning_phase` which performs trace integration when 0, weight update when 1.

# %%
synapse = Synapse(
    parameters="""
        eta = 0.5 : projection # Learning rate
        learning_phase = 0.0 : projection # Flag to allow learning only at the end of a trial
        error = 0.0 : projection # Reward received
        mean_error = 0.0 : projection # Mean Reward received
        max_weight_change = 0.0003 : projection # Clip the weight changes
    """,
    equations="""
        # Trace
        trace += if learning_phase < 0.5:
                    power(pre.rprev * (post.delta_x), 3)
                 else:
                    0.0

        # Weight update only at the end of the trial
        delta_w = if learning_phase > 0.5:
                eta * trace * (mean_error) * (error - mean_error)
             else:
                 0.0 : min=-max_weight_change, max=max_weight_change
        w -= if learning_phase > 0.5:
                delta_w
             else:
                 0.0
    """
)

# %% [markdown]
# We model the DNMS task of Miconi. The RC network has two inputs A and B. The reservoir has 200 neurons, 3 of which have constant rates.

# %%
# Input population
inp = Population(2, Neuron(parameters="r=0.0"))

# Recurrent population
N = 200
pop = Population(N, neuron)
pop[1].constant = 1.0
pop[10].constant = 1.0
pop[11].constant = -1.0
pop.x = Uniform(-0.1, 0.1)

# %% [markdown]
# Input weights are uniformly distributes between -1 and 1.
#
# Recurrent weights and normally distributed, with a coupling strength of $g=1.5$ (edge of chaos).
#
# Connections are all-to-all (fully connected).

# %%
# Input weights
Wi = Projection(inp, pop, 'in')
Wi.connect_all_to_all(weights=Uniform(-1.0, 1.0))

# Recurrent weights
g = 1.5
Wrec = Projection(pop, pop, 'exc', synapse)
Wrec.connect_all_to_all(weights=Normal(0., g/np.sqrt(N)), allow_self_connections=True)

# %%
compile()
# Out:
# WARNING: unrecognized arguments: ['-f', '/run/user/1000/jupyter/kernel-d97f0ca8-df5d-43f5-b45b-1f4b2e9e155a.json']
# Compiling...
# OK

# %% [markdown]
# The output of the reservoir is chosen to be the neuron of index 100.

# %%
output_neuron = 100

# %% [markdown]
# We record the rates inside the reservoir:

# %%
m = Monitor(pop, ['r'])

# %% [markdown]
# Parameters defining the task:

# %%
# Compute the mean reward per trial
R_mean = np.zeros((2, 2))
alpha = 0.75 # 0.33

# Durations
d_stim = 200
d_delay= 200
d_response = 400
d_execution= 200

# %% [markdown]
# Definition of a DNMS trial (AA, AB, BA, BB):

# %%
def dnms_trial(trial, first, second, R_mean):
    traces = []
    # Reinit network
    pop.x = Uniform(-0.1, 0.1).get_values(N)
    pop.r = np.tanh(pop.x)
    pop[1].r = np.tanh(1.0)
    pop[10].r = np.tanh(1.0)
    pop[11].r = np.tanh(-1.0)
    # First input
    inp[first].r = 1.0
    simulate(d_stim)
    # Delay
    inp.r = 0.0
    simulate(d_delay)
    # Second input
    inp[second].r = 1.0
    simulate(d_stim)
    # Relaxation
    inp.r = 0.0
    simulate(d_response)
    # Read the output
    rec = m.get()
    # traces = n.get('trace')
    # Compute the target
    target = 0.98 if first != second else -0.98
    # Response if over the last 200 ms
    output = rec['r'][-int(d_execution):, output_neuron] # neuron 100 over the last 200 ms
    # Compute the error
    error = np.mean(np.abs(target - output))
    print('Target:', target, '\tOutput:', "%0.3f" % np.mean(output), '\tError:',  "%0.3f" % error, '\tMean:', "%0.3f" % R_mean[first, second])
    # The first 25 trial do not learn, to let R_mean get realistic values
    if trial > 25:
        # Apply the learning rule
        Wrec.learning_phase = 1.0
        Wrec.error = error
        Wrec.mean_error = R_mean[first, second]
        # Learn for one step
        step()
        # Reset the traces
        Wrec.learning_phase = 0.0
        Wrec.trace = 0.0
        _ = m.get() # to flush the recording of the last step

    # Update the mean reward
    R_mean[first, second] = alpha * R_mean[first, second] + (1.- alpha) * error

    return rec, traces, R_mean

# %%
# Initial weights
init_w = Wrec.w

# Many trials of each type
try:
    for trial in range(2500):
        print('Trial', trial)
        recordsAA, tracesAA, R_mean = dnms_trial (trial, 0, 0, R_mean)
        recordsAB, tracesAB, R_mean = dnms_trial (trial, 0, 1, R_mean)
        recordsBA, tracesBA, R_mean = dnms_trial (trial, 1, 0, R_mean)
        recordsBB, tracesBB, R_mean = dnms_trial (trial, 1, 1, R_mean)
        if trial == 0:
            initialAA = recordsAA['r']
            initialAB = recordsAB['r']
            initialBA = recordsBA['r']
            initialBB = recordsBB['r']
except KeyboardInterrupt:
    pass

# Final weights
final_w = Wrec.w
# Out:
# Trial 0
# Target: -0.98 	Output: -0.639 	Error: 0.341 	Mean: 0.000
# Target: 0.98 	Output: -0.678 	Error: 1.658 	Mean: 0.000
# Target: 0.98 	Output: -0.411 	Error: 1.391 	Mean: 0.000
# Target: -0.98 	Output: -0.389 	Error: 0.591 	Mean: 0.000
# Trial 1
# Target: -0.98 	Output: -0.685 	Error: 0.295 	Mean: 0.085
# Target: 0.98 	Output: -0.575 	Error: 1.555 	Mean: 0.414
# Target: 0.98 	Output: -0.380 	Error: 1.360 	Mean: 0.348
# Target: -0.98 	Output: -0.369 	Error: 0.611 	Mean: 0.148
# Trial 2
# Target: -0.98 	Output: -0.587 	Error: 0.393 	Mean: 0.138
# Target: 0.98 	Output: -0.419 	Error: 1.399 	Mean: 0.700
# Target: 0.98 	Output: -0.437 	Error: 1.417 	Mean: 0.601
# Target: -0.98 	Output: -0.173 	Error: 0.807 	Mean: 0.264
# Trial 3
# Target: -0.98 	Output: -0.727 	Error: 0.253 	Mean: 0.201
# Target: 0.98 	Output: -0.533 	Error: 1.513 	Mean: 0.875
# Target: 0.98 	Output: -0.542 	Error: 1.522 	Mean: 0.805
# Target: -0.98 	Output: -0.672 	Error: 0.308 	Mean: 0.400
# Trial 4
# Target: -0.98 	Output: -0.654 	Error: 0.326 	Mean: 0.214
# Target: 0.98 	Output: -0.568 	Error: 1.548 	Mean: 1.034
# Target: 0.98 	Output: -0.511 	Error: 1.491 	Mean: 0.984
# Target: -0.98 	Output: -0.519 	Error: 0.461 	Mean: 0.377
# Trial 5
# Target: -0.98 	Output: -0.660 	Error: 0.320 	Mean: 0.242
# Target: 0.98 	Output: -0.627 	Error: 1.607 	Mean: 1.163
# Target: 0.98 	Output: -0.555 	Error: 1.535 	Mean: 1.111
# Target: -0.98 	Output: -0.311 	Error: 0.669 	Mean: 0.398
# Trial 6
# Target: -0.98 	Output: -0.625 	Error: 0.355 	Mean: 0.262
# Target: 0.98 	Output: -0.553 	Error: 1.533 	Mean: 1.274
# Target: 0.98 	Output: -0.455 	Error: 1.435 	Mean: 1.217
# Target: -0.98 	Output: -0.351 	Error: 0.629 	Mean: 0.466
# Trial 7
# Target: -0.98 	Output: -0.628 	Error: 0.352 	Mean: 0.285
# Target: 0.98 	Output: -0.471 	Error: 1.451 	Mean: 1.339
# Target: 0.98 	Output: -0.635 	Error: 1.615 	Mean: 1.271
# Target: -0.98 	Output: -0.543 	Error: 0.437 	Mean: 0.507
# Trial 8
# Target: -0.98 	Output: -0.643 	Error: 0.337 	Mean: 0.302
# Target: 0.98 	Output: -0.520 	Error: 1.500 	Mean: 1.367
# Target: 0.98 	Output: -0.639 	Error: 1.619 	Mean: 1.357
# Target: -0.98 	Output: -0.436 	Error: 0.544 	Mean: 0.489
# Trial 9
# Target: -0.98 	Output: -0.666 	Error: 0.314 	Mean: 0.311
# Target: 0.98 	Output: -0.424 	Error: 1.404 	Mean: 1.400
# Target: 0.98 	Output: -0.484 	Error: 1.464 	Mean: 1.423
# Target: -0.98 	Output: -0.473 	Error: 0.507 	Mean: 0.503
# Trial 10
# Target: -0.98 	Output: -0.453 	Error: 0.527 	Mean: 0.311
# Target: 0.98 	Output: -0.518 	Error: 1.498 	Mean: 1.401
# Target: 0.98 	Output: -0.468 	Error: 1.448 	Mean: 1.433
# Target: -0.98 	Output: -0.365 	Error: 0.615 	Mean: 0.504
# Trial 11
# Target: -0.98 	Output: -0.502 	Error: 0.478 	Mean: 0.365
# Target: 0.98 	Output: -0.573 	Error: 1.553 	Mean: 1.425
# Target: 0.98 	Output: -0.492 	Error: 1.472 	Mean: 1.437
# Target: -0.98 	Output: -0.534 	Error: 0.446 	Mean: 0.532
# Trial 12
# Target: -0.98 	Output: -0.678 	Error: 0.302 	Mean: 0.393
# Target: 0.98 	Output: -0.570 	Error: 1.550 	Mean: 1.457
# Target: 0.98 	Output: -0.627 	Error: 1.607 	Mean: 1.446
# Target: -0.98 	Output: -0.456 	Error: 0.524 	Mean: 0.510
# Trial 13
# Target: -0.98 	Output: -0.584 	Error: 0.396 	Mean: 0.371
# Target: 0.98 	Output: -0.491 	Error: 1.471 	Mean: 1.480
# Target: 0.98 	Output: -0.548 	Error: 1.528 	Mean: 1.486
# Target: -0.98 	Output: -0.605 	Error: 0.375 	Mean: 0.514
# Trial 14
# Target: -0.98 	Output: -0.767 	Error: 0.213 	Mean: 0.377
# Target: 0.98 	Output: -0.549 	Error: 1.529 	Mean: 1.478
# Target: 0.98 	Output: -0.474 	Error: 1.454 	Mean: 1.496
# Target: -0.98 	Output: -0.433 	Error: 0.547 	Mean: 0.479
# Trial 15
# Target: -0.98 	Output: -0.714 	Error: 0.266 	Mean: 0.336
# Target: 0.98 	Output: -0.562 	Error: 1.542 	Mean: 1.491
# Target: 0.98 	Output: -0.424 	Error: 1.404 	Mean: 1.486
# Target: -0.98 	Output: -0.309 	Error: 0.671 	Mean: 0.496
# Trial 16
# Target: -0.98 	Output: -0.613 	Error: 0.367 	Mean: 0.318
# Target: 0.98 	Output: -0.631 	Error: 1.611 	Mean: 1.504
# Target: 0.98 	Output: -0.730 	Error: 1.710 	Mean: 1.465
# Target: -0.98 	Output: -0.062 	Error: 0.918 	Mean: 0.540
# Trial 17
# Target: -0.98 	Output: -0.686 	Error: 0.294 	Mean: 0.330
# Target: 0.98 	Output: -0.524 	Error: 1.504 	Mean: 1.530
# Target: 0.98 	Output: -0.674 	Error: 1.654 	Mean: 1.526
# Target: -0.98 	Output: -0.510 	Error: 0.470 	Mean: 0.634
# Trial 18
# Target: -0.98 	Output: -0.701 	Error: 0.279 	Mean: 0.321
# Target: 0.98 	Output: -0.483 	Error: 1.463 	Mean: 1.524
# Target: 0.98 	Output: -0.598 	Error: 1.578 	Mean: 1.558
# Target: -0.98 	Output: -0.437 	Error: 0.543 	Mean: 0.593
# Trial 19
# Target: -0.98 	Output: -0.583 	Error: 0.397 	Mean: 0.311
# Target: 0.98 	Output: -0.661 	Error: 1.641 	Mean: 1.509
# Target: 0.98 	Output: -0.537 	Error: 1.517 	Mean: 1.563
# Target: -0.98 	Output: -0.396 	Error: 0.584 	Mean: 0.581
# Trial 20
# Target: -0.98 	Output: -0.819 	Error: 0.161 	Mean: 0.332
# Target: 0.98 	Output: -0.528 	Error: 1.508 	Mean: 1.542
# Target: 0.98 	Output: -0.567 	Error: 1.547 	Mean: 1.552
# Target: -0.98 	Output: -0.465 	Error: 0.515 	Mean: 0.581
# Trial 21
# Target: -0.98 	Output: -0.785 	Error: 0.195 	Mean: 0.289
# Target: 0.98 	Output: -0.385 	Error: 1.365 	Mean: 1.533
# Target: 0.98 	Output: -0.468 	Error: 1.448 	Mean: 1.551
# Target: -0.98 	Output: -0.516 	Error: 0.464 	Mean: 0.565
# Trial 22
# Target: -0.98 	Output: -0.622 	Error: 0.358 	Mean: 0.266
# Target: 0.98 	Output: -0.486 	Error: 1.466 	Mean: 1.491
# Target: 0.98 	Output: -0.719 	Error: 1.699 	Mean: 1.525
# Target: -0.98 	Output: -0.413 	Error: 0.567 	Mean: 0.540
# Trial 23
# Target: -0.98 	Output: -0.672 	Error: 0.308 	Mean: 0.289
# Target: 0.98 	Output: -0.672 	Error: 1.652 	Mean: 1.485
# Target: 0.98 	Output: -0.458 	Error: 1.438 	Mean: 1.568
# Target: -0.98 	Output: -0.520 	Error: 0.460 	Mean: 0.546
# Trial 24
# Target: -0.98 	Output: -0.598 	Error: 0.382 	Mean: 0.293
# Target: 0.98 	Output: -0.462 	Error: 1.442 	Mean: 1.527
# Target: 0.98 	Output: -0.495 	Error: 1.475 	Mean: 1.536
# Target: -0.98 	Output: -0.325 	Error: 0.655 	Mean: 0.525
# Trial 25
# Target: -0.98 	Output: -0.657 	Error: 0.323 	Mean: 0.315
# Target: 0.98 	Output: -0.508 	Error: 1.488 	Mean: 1.506
# Target: 0.98 	Output: -0.519 	Error: 1.499 	Mean: 1.521
# Target: -0.98 	Output: -0.304 	Error: 0.676 	Mean: 0.557
# Trial 26
# Target: -0.98 	Output: -0.682 	Error: 0.298 	Mean: 0.317
# Target: 0.98 	Output: -0.630 	Error: 1.610 	Mean: 1.501
# Target: 0.98 	Output: -0.491 	Error: 1.471 	Mean: 1.515
# Target: -0.98 	Output: -0.495 	Error: 0.485 	Mean: 0.587
# Trial 27
# Target: -0.98 	Output: -0.516 	Error: 0.464 	Mean: 0.312
# Target: 0.98 	Output: -0.353 	Error: 1.333 	Mean: 1.528
# Target: 0.98 	Output: -0.566 	Error: 1.546 	Mean: 1.504
# Target: -0.98 	Output: -0.659 	Error: 0.321 	Mean: 0.561
# Trial 28
# Target: -0.98 	Output: -0.670 	Error: 0.310 	Mean: 0.350
# Target: 0.98 	Output: -0.408 	Error: 1.388 	Mean: 1.479
# Target: 0.98 	Output: -0.480 	Error: 1.460 	Mean: 1.515
# Target: -0.98 	Output: -0.524 	Error: 0.456 	Mean: 0.501
# Trial 29
# Target: -0.98 	Output: -0.568 	Error: 0.412 	Mean: 0.340
# Target: 0.98 	Output: -0.169 	Error: 1.149 	Mean: 1.457
# Target: 0.98 	Output: -0.605 	Error: 1.585 	Mean: 1.501
# Target: -0.98 	Output: -0.373 	Error: 0.607 	Mean: 0.490
# Trial 30
# Target: -0.98 	Output: -0.298 	Error: 0.682 	Mean: 0.358
# Target: 0.98 	Output: -0.348 	Error: 1.328 	Mean: 1.380
# Target: 0.98 	Output: -0.453 	Error: 1.433 	Mean: 1.522
# Target: -0.98 	Output: -0.571 	Error: 0.409 	Mean: 0.519
# Trial 31
# Target: -0.98 	Output: -0.229 	Error: 0.751 	Mean: 0.439
# Target: 0.98 	Output: -0.704 	Error: 1.684 	Mean: 1.367
# Target: 0.98 	Output: -0.601 	Error: 1.581 	Mean: 1.500
# Target: -0.98 	Output: -0.542 	Error: 0.438 	Mean: 0.492
# Trial 32
# Target: -0.98 	Output: -0.403 	Error: 0.577 	Mean: 0.517
# Target: 0.98 	Output: -0.165 	Error: 1.145 	Mean: 1.446
# Target: 0.98 	Output: -0.467 	Error: 1.447 	Mean: 1.520
# Target: -0.98 	Output: -0.538 	Error: 0.442 	Mean: 0.478
# Trial 33
# Target: -0.98 	Output: -0.215 	Error: 0.765 	Mean: 0.532
# Target: 0.98 	Output: -0.505 	Error: 1.485 	Mean: 1.371
# Target: 0.98 	Output: -0.620 	Error: 1.600 	Mean: 1.502
# Target: -0.98 	Output: -0.618 	Error: 0.362 	Mean: 0.469
# Trial 34
# Target: -0.98 	Output: -0.408 	Error: 0.572 	Mean: 0.590
# Target: 0.98 	Output: -0.188 	Error: 1.168 	Mean: 1.399
# Target: 0.98 	Output: -0.394 	Error: 1.374 	Mean: 1.526
# Target: -0.98 	Output: -0.418 	Error: 0.562 	Mean: 0.442
# Trial 35
# Target: -0.98 	Output: -0.241 	Error: 0.739 	Mean: 0.586
# Target: 0.98 	Output: -0.299 	Error: 1.279 	Mean: 1.342
# Target: 0.98 	Output: -0.513 	Error: 1.493 	Mean: 1.488
# Target: -0.98 	Output: -0.467 	Error: 0.513 	Mean: 0.472
# Trial 36
# Target: -0.98 	Output: -0.344 	Error: 0.636 	Mean: 0.624
# Target: 0.98 	Output: -0.259 	Error: 1.239 	Mean: 1.326
# Target: 0.98 	Output: -0.435 	Error: 1.415 	Mean: 1.490
# Target: -0.98 	Output: -0.469 	Error: 0.511 	Mean: 0.483
# Trial 37
# Target: -0.98 	Output: -0.451 	Error: 0.529 	Mean: 0.627
# Target: 0.98 	Output: -0.464 	Error: 1.444 	Mean: 1.304
# Target: 0.98 	Output: -0.489 	Error: 1.469 	Mean: 1.471
# Target: -0.98 	Output: -0.469 	Error: 0.511 	Mean: 0.490
# Trial 38
# Target: -0.98 	Output: -0.102 	Error: 0.878 	Mean: 0.602
# Target: 0.98 	Output: -0.479 	Error: 1.459 	Mean: 1.339
# Target: 0.98 	Output: -0.467 	Error: 1.447 	Mean: 1.470
# Target: -0.98 	Output: -0.693 	Error: 0.287 	Mean: 0.495
# Trial 39
# Target: -0.98 	Output: -0.403 	Error: 0.577 	Mean: 0.671
# Target: 0.98 	Output: -0.222 	Error: 1.202 	Mean: 1.369
# Target: 0.98 	Output: -0.395 	Error: 1.375 	Mean: 1.464
# Target: -0.98 	Output: -0.475 	Error: 0.505 	Mean: 0.443
# Trial 40
# Target: -0.98 	Output: -0.460 	Error: 0.520 	Mean: 0.648
# Target: 0.98 	Output: -0.064 	Error: 1.044 	Mean: 1.327
# Target: 0.98 	Output: -0.437 	Error: 1.417 	Mean: 1.442
# Target: -0.98 	Output: -0.588 	Error: 0.392 	Mean: 0.458
# Trial 41
# Target: -0.98 	Output: -0.514 	Error: 0.466 	Mean: 0.616
# Target: 0.98 	Output: -0.182 	Error: 1.162 	Mean: 1.257
# Target: 0.98 	Output: -0.513 	Error: 1.493 	Mean: 1.436
# Target: -0.98 	Output: -0.521 	Error: 0.459 	Mean: 0.442
# Trial 42
# Target: -0.98 	Output: -0.445 	Error: 0.535 	Mean: 0.578
# Target: 0.98 	Output: -0.234 	Error: 1.214 	Mean: 1.233
# Target: 0.98 	Output: -0.617 	Error: 1.597 	Mean: 1.450
# Target: -0.98 	Output: -0.567 	Error: 0.413 	Mean: 0.446
# Trial 43
# Target: -0.98 	Output: -0.523 	Error: 0.457 	Mean: 0.568
# Target: 0.98 	Output: -0.268 	Error: 1.248 	Mean: 1.228
# Target: 0.98 	Output: -0.318 	Error: 1.298 	Mean: 1.487
# Target: -0.98 	Output: -0.474 	Error: 0.506 	Mean: 0.438
# Trial 44
# Target: -0.98 	Output: -0.573 	Error: 0.407 	Mean: 0.540
# Target: 0.98 	Output: -0.170 	Error: 1.150 	Mean: 1.233
# Target: 0.98 	Output: -0.393 	Error: 1.373 	Mean: 1.440
# Target: -0.98 	Output: -0.419 	Error: 0.561 	Mean: 0.455
# Trial 45
# Target: -0.98 	Output: -0.277 	Error: 0.703 	Mean: 0.507
# Target: 0.98 	Output: 0.050 	Error: 0.930 	Mean: 1.212
# Target: 0.98 	Output: -0.325 	Error: 1.305 	Mean: 1.423
# Target: -0.98 	Output: -0.554 	Error: 0.426 	Mean: 0.481
# Trial 46
# Target: -0.98 	Output: -0.482 	Error: 0.498 	Mean: 0.556
# Target: 0.98 	Output: 0.146 	Error: 0.834 	Mean: 1.142
# Target: 0.98 	Output: -0.365 	Error: 1.345 	Mean: 1.394
# Target: -0.98 	Output: -0.227 	Error: 0.753 	Mean: 0.467
# Trial 47
# Target: -0.98 	Output: -0.684 	Error: 0.296 	Mean: 0.542
# Target: 0.98 	Output: 0.029 	Error: 0.951 	Mean: 1.065
# Target: 0.98 	Output: -0.145 	Error: 1.125 	Mean: 1.381
# Target: -0.98 	Output: -0.412 	Error: 0.568 	Mean: 0.539
# Trial 48
# Target: -0.98 	Output: -0.317 	Error: 0.663 	Mean: 0.480
# Target: 0.98 	Output: 0.332 	Error: 0.648 	Mean: 1.036
# Target: 0.98 	Output: -0.252 	Error: 1.232 	Mean: 1.317
# Target: -0.98 	Output: -0.277 	Error: 0.703 	Mean: 0.546
# Trial 49
# Target: -0.98 	Output: -0.181 	Error: 0.799 	Mean: 0.526
# Target: 0.98 	Output: 0.269 	Error: 0.711 	Mean: 0.939
# Target: 0.98 	Output: -0.336 	Error: 1.316 	Mean: 1.296
# Target: -0.98 	Output: -0.149 	Error: 0.831 	Mean: 0.585
# Trial 50
# Target: -0.98 	Output: -0.010 	Error: 0.970 	Mean: 0.594
# Target: 0.98 	Output: 0.099 	Error: 0.881 	Mean: 0.882
# Target: 0.98 	Output: -0.143 	Error: 1.123 	Mean: 1.301
# Target: -0.98 	Output: 0.040 	Error: 1.020 	Mean: 0.647
# Trial 51
# Target: -0.98 	Output: -0.167 	Error: 0.813 	Mean: 0.688
# Target: 0.98 	Output: 0.086 	Error: 0.894 	Mean: 0.882
# Target: 0.98 	Output: -0.120 	Error: 1.100 	Mean: 1.257
# Target: -0.98 	Output: -0.024 	Error: 0.956 	Mean: 0.740
# Trial 52
# Target: -0.98 	Output: -0.477 	Error: 0.503 	Mean: 0.719
# Target: 0.98 	Output: 0.343 	Error: 0.637 	Mean: 0.885
# Target: 0.98 	Output: -0.251 	Error: 1.231 	Mean: 1.217
# Target: -0.98 	Output: -0.281 	Error: 0.699 	Mean: 0.794
# Trial 53
# Target: -0.98 	Output: -0.634 	Error: 0.346 	Mean: 0.665
# Target: 0.98 	Output: 0.107 	Error: 0.873 	Mean: 0.823
# Target: 0.98 	Output: -0.448 	Error: 1.428 	Mean: 1.221
# Target: -0.98 	Output: 0.046 	Error: 1.026 	Mean: 0.770
# Trial 54
# Target: -0.98 	Output: -0.581 	Error: 0.399 	Mean: 0.585
# Target: 0.98 	Output: 0.126 	Error: 0.854 	Mean: 0.835
# Target: 0.98 	Output: -0.339 	Error: 1.319 	Mean: 1.272
# Target: -0.98 	Output: -0.124 	Error: 0.856 	Mean: 0.834
# Trial 55
# Target: -0.98 	Output: -0.552 	Error: 0.428 	Mean: 0.539
# Target: 0.98 	Output: 0.042 	Error: 0.938 	Mean: 0.840
# Target: 0.98 	Output: -0.217 	Error: 1.197 	Mean: 1.284
# Target: -0.98 	Output: -0.113 	Error: 0.867 	Mean: 0.840
# Trial 56
# Target: -0.98 	Output: -0.355 	Error: 0.625 	Mean: 0.511
# Target: 0.98 	Output: 0.120 	Error: 0.860 	Mean: 0.864
# Target: 0.98 	Output: -0.138 	Error: 1.118 	Mean: 1.262
# Target: -0.98 	Output: -0.127 	Error: 0.853 	Mean: 0.847
# Trial 57
# Target: -0.98 	Output: -0.525 	Error: 0.455 	Mean: 0.540
# Target: 0.98 	Output: 0.346 	Error: 0.634 	Mean: 0.863
# Target: 0.98 	Output: -0.192 	Error: 1.172 	Mean: 1.226
# Target: -0.98 	Output: -0.186 	Error: 0.794 	Mean: 0.848
# Trial 58
# Target: -0.98 	Output: -0.595 	Error: 0.385 	Mean: 0.519
# Target: 0.98 	Output: 0.079 	Error: 0.901 	Mean: 0.806
# Target: 0.98 	Output: -0.367 	Error: 1.347 	Mean: 1.213
# Target: -0.98 	Output: -0.200 	Error: 0.780 	Mean: 0.835
# Trial 59
# Target: -0.98 	Output: -0.661 	Error: 0.319 	Mean: 0.485
# Target: 0.98 	Output: 0.211 	Error: 0.769 	Mean: 0.830
# Target: 0.98 	Output: -0.155 	Error: 1.135 	Mean: 1.246
# Target: -0.98 	Output: -0.370 	Error: 0.610 	Mean: 0.821
# Trial 60
# Target: -0.98 	Output: -0.573 	Error: 0.407 	Mean: 0.444
# Target: 0.98 	Output: 0.303 	Error: 0.677 	Mean: 0.815
# Target: 0.98 	Output: -0.239 	Error: 1.219 	Mean: 1.218
# Target: -0.98 	Output: -0.046 	Error: 0.934 	Mean: 0.768
# Trial 61
# Target: -0.98 	Output: -0.700 	Error: 0.280 	Mean: 0.434
# Target: 0.98 	Output: 0.375 	Error: 0.605 	Mean: 0.780
# Target: 0.98 	Output: -0.581 	Error: 1.561 	Mean: 1.219
# Target: -0.98 	Output: -0.562 	Error: 0.418 	Mean: 0.810
# Trial 62
# Target: -0.98 	Output: -0.709 	Error: 0.271 	Mean: 0.396
# Target: 0.98 	Output: 0.160 	Error: 0.820 	Mean: 0.736
# Target: 0.98 	Output: -0.112 	Error: 1.092 	Mean: 1.304
# Target: -0.98 	Output: -0.400 	Error: 0.580 	Mean: 0.712
# Trial 63
# Target: -0.98 	Output: -0.439 	Error: 0.541 	Mean: 0.365
# Target: 0.98 	Output: -0.247 	Error: 1.227 	Mean: 0.757
# Target: 0.98 	Output: -0.271 	Error: 1.251 	Mean: 1.251
# Target: -0.98 	Output: -0.575 	Error: 0.405 	Mean: 0.679
# Trial 64
# Target: -0.98 	Output: -0.484 	Error: 0.496 	Mean: 0.409
# Target: 0.98 	Output: 0.319 	Error: 0.661 	Mean: 0.875
# Target: 0.98 	Output: 0.077 	Error: 0.903 	Mean: 1.251
# Target: -0.98 	Output: -0.375 	Error: 0.605 	Mean: 0.610
# Trial 65
# Target: -0.98 	Output: -0.296 	Error: 0.684 	Mean: 0.431
# Target: 0.98 	Output: 0.200 	Error: 0.780 	Mean: 0.821
# Target: 0.98 	Output: 0.049 	Error: 0.931 	Mean: 1.164
# Target: -0.98 	Output: -0.412 	Error: 0.568 	Mean: 0.609
# Trial 66
# Target: -0.98 	Output: -0.147 	Error: 0.833 	Mean: 0.494
# Target: 0.98 	Output: 0.217 	Error: 0.763 	Mean: 0.811
# Target: 0.98 	Output: -0.225 	Error: 1.205 	Mean: 1.106
# Target: -0.98 	Output: -0.601 	Error: 0.379 	Mean: 0.599
# Trial 67
# Target: -0.98 	Output: -0.479 	Error: 0.501 	Mean: 0.579
# Target: 0.98 	Output: 0.334 	Error: 0.646 	Mean: 0.799
# Target: 0.98 	Output: -0.301 	Error: 1.281 	Mean: 1.130
# Target: -0.98 	Output: -0.563 	Error: 0.417 	Mean: 0.544
# Trial 68
# Target: -0.98 	Output: -0.333 	Error: 0.647 	Mean: 0.559
# Target: 0.98 	Output: 0.413 	Error: 0.567 	Mean: 0.761
# Target: 0.98 	Output: 0.009 	Error: 0.971 	Mean: 1.168
# Target: -0.98 	Output: -0.422 	Error: 0.558 	Mean: 0.512
# Trial 69
# Target: -0.98 	Output: -0.568 	Error: 0.412 	Mean: 0.581
# Target: -0.98 	Output: -0.936 	Error: 0.044 	Mean: 0.088
# Trial 533
# Target: -0.98 	Output: -0.959 	Error: 0.027 	Mean: 0.041
# Target: 0.98 	Output: 0.988 	Error: 0.008 	Mean: 0.019
# Target: 0.98 	Output: 0.952 	Error: 0.028 	Mean: 0.013
# Target: -0.98 	Output: -0.936 	Error: 0.044 	Mean: 0.077
# Trial 534
# Target: -0.98 	Output: -0.931 	Error: 0.050 	Mean: 0.037
# Target: 0.98 	Output: 0.986 	Error: 0.007 	Mean: 0.016
# Target: 0.98 	Output: 0.981 	Error: 0.002 	Mean: 0.017
# Target: -0.98 	Output: -0.948 	Error: 0.032 	Mean: 0.069
# Trial 535
# Target: -0.98 	Output: -0.971 	Error: 0.014 	Mean: 0.040
# Target: 0.98 	Output: 0.978 	Error: 0.007 	Mean: 0.014
# Target: 0.98 	Output: 0.972 	Error: 0.008 	Mean: 0.013
# Target: -0.98 	Output: -0.929 	Error: 0.051 	Mean: 0.060
# Trial 536
# Target: -0.98 	Output: -0.914 	Error: 0.067 	Mean: 0.034
# Target: 0.98 	Output: 0.991 	Error: 0.011 	Mean: 0.012
# Target: 0.98 	Output: 0.968 	Error: 0.012 	Mean: 0.012
# Target: -0.98 	Output: -0.905 	Error: 0.075 	Mean: 0.058
# Trial 537
# Target: -0.98 	Output: -0.930 	Error: 0.051 	Mean: 0.042
# Target: 0.98 	Output: 0.990 	Error: 0.010 	Mean: 0.012
# Target: 0.98 	Output: 0.962 	Error: 0.018 	Mean: 0.012
# Target: -0.98 	Output: -0.931 	Error: 0.049 	Mean: 0.062
# Trial 538
# Target: -0.98 	Output: -0.957 	Error: 0.028 	Mean: 0.044
# Target: 0.98 	Output: 0.990 	Error: 0.010 	Mean: 0.012
# Target: 0.98 	Output: 0.961 	Error: 0.019 	Mean: 0.014
# Target: -0.98 	Output: -0.932 	Error: 0.048 	Mean: 0.059
# Trial 539
# Target: -0.98 	Output: -0.964 	Error: 0.022 	Mean: 0.040
# Target: 0.98 	Output: 0.983 	Error: 0.006 	Mean: 0.011
# Target: 0.98 	Output: 0.956 	Error: 0.024 	Mean: 0.015
# Target: -0.98 	Output: -0.941 	Error: 0.039 	Mean: 0.056
# Trial 540
# Target: -0.98 	Output: -0.976 	Error: 0.013 	Mean: 0.036
# Target: 0.98 	Output: 0.989 	Error: 0.009 	Mean: 0.010
# Target: 0.98 	Output: 0.970 	Error: 0.010 	Mean: 0.017
# Target: -0.98 	Output: -0.894 	Error: 0.086 	Mean: 0.052
# Trial 541
# Target: -0.98 	Output: -0.944 	Error: 0.046 	Mean: 0.030
# Target: 0.98 	Output: 0.860 	Error: 0.120 	Mean: 0.010

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20, 20))
ax = plt.subplot(231)
ax.imshow(recordsAA['r'].T, aspect='auto', origin='lower')
ax.set_title('Population')
ax = plt.subplot(232)
ax.plot(np.mean(initialAA[:, output_neuron:output_neuron+1], axis=1), label='before')
ax.plot(np.mean(recordsAA['r'][:, output_neuron:output_neuron+1], axis=1), label='after')
ax.set_ylim((-1., 1.))
ax.legend()
ax.set_title('Output AA -1')
ax = plt.subplot(233)
ax.plot(np.mean(initialBA[:, output_neuron:output_neuron+1], axis=1), label='before')
ax.plot(np.mean(recordsBA['r'][:, output_neuron:output_neuron+1], axis=1), label='after')
ax.set_ylim((-1., 1.))
ax.legend()
ax.set_title('Output BA +1')
ax = plt.subplot(235)
ax.plot(np.mean(initialAB[:, output_neuron:output_neuron+1], axis=1), label='before')
ax.plot(np.mean(recordsAB['r'][:, output_neuron:output_neuron+1], axis=1), label='after')
ax.set_ylim((-1., 1.))
ax.set_title('Output AB +1')
ax = plt.subplot(236)
ax.plot(np.mean(initialBB[:, output_neuron:output_neuron+1], axis=1), label='before')
ax.plot(np.mean(recordsBB['r'][:, output_neuron:output_neuron+1], axis=1), label='after')
ax.set_ylim((-1., 1.))
ax.set_title('Output BB -1')
plt.show()
